# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from src import game_of_life

# %%
game = game_of_life.GameOfLife()

# %%
game.animate_result(t=100)

# %%
glider = game_of_life.GameOfLife_Glider()

# %%
glider.animate_result(100)

# %%
puffer = game_of_life.GameOfLife_Puffer()

# %%
puffer.animate_result(100)

# %%
dimond = game_of_life.GameOfLife_Dimond()

# %%
dimond.animate_result(100)

# %%
shaker = game_of_life.GameOfLife_Shaker()

# %%
shaker.animate_result(100)

# %%
mazentic = game_of_life.Mazentic()
mazentic.animate_result(100)

# %%
flakes = game_of_life.Flakes()
flakes.animate_result(100)
