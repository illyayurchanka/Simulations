# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import itertools
from src import task1, task2

# %%
game = task1.Automata(rule_num=30, width=500, height=1000, central=False, reversable=False)
game.plot_result()
# Out:
# RULE: 30
# Initialization Random
# Non-Reversable

# %%
_ = task2.plot_entropy_comparison(height=500)
# Out:
# Computing S(t) for Rule 110...
# Computing S(t) for Rule 122R...

# %%
from src.task3 import CoarseGrainedAutomata, compare_coarse_entropy
_ = compare_coarse_entropy(width=500, height=15000, n_black=41, m=5, T=300)
# Out:
# Rule 110
#
# Rule 122R
